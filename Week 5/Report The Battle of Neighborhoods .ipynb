# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# ## Introduction

# %% [markdown]
# Scarborough is a popular destination for new immigrants in Canada. As a result, it is one of the most diverse and multicultural areas in the Greater Toronto Area. If people are aware about the new city, the process of relocation, renting or buying a house becomes easier.

# %% [markdown]
# ## Business Problem

# %% [markdown]
# People spend so much time researching houses based on price, reputed schools for their children, access to Super market, medical shops, grocery shops, mall, theatre, hospital etc. The purpose of this project is to explore Scarborough neighborhood so that people find it easy to buy house-based housing prices, access to point of interests and school ratings.

# %% [markdown]
# ## Data Approach

# %% [markdown]
# This section describes our data approach to find a solution to the business problem.
# we will gather data about the neighborhood, housing prices and school ratings of Scarborough. We will use foursquare API to research the neighborhood of Scarborough.  Foursquare is a location data provider with information on venues and events within an area of interest. Such information includes venue names, locations, menus and even photos. Foursquare API will be used as data source for gathering information on neighborhood.
# For the housing prices we will use data from “https://www.kaggle.com/mnabaee/ontarioproperties”
# To help parents to identify the school reviews we will use data from “https://www.greatschools.org”.

# %% [markdown]
# ## Methodology

# %% [markdown]
# This section describes the process data extraction,transformation and reporting Scarborough neighbourhood. For the ease of analysis we have taken into account of nearby venus within a range of 500 KM , near by schools and average rates of houses.
#
# Please find the below process
# 1. Scrape data from https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M to get the postal code details
# 2. Extract Latitue and Longitude details from https://cocl.us/Geospatial_data
# 3. Merge the above to data sets to obtain the deo details of scarborough neighborhood.
# 4. Use forsquqre API to get the venue details of neighborhood
# 5. Cluster the neighborhood to 5 cluster to identify similarity using K means Clustering
# 6. Get the housing prices we will use data from “https://www.kaggle.com/mnabaee/ontarioproperties
# 7. Get the school reviews we will use data from “https://www.greatschools.org”.
# 8. Create bar chart of average housing prices of scarborough neighborhood.
# 9. create a bar chart of school reviews of scarborough neighborhood.

# %% [markdown]
# #### Geo details of scarborough neighborhood

# %% [markdown]
# ![Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg](attachment:Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg)

# %% [markdown]
# #### Map of scarborough along with neighborhoods

# %% [markdown]
# ![Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg](attachment:Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg)

# %% [markdown]
# ####  Result of foursqure API with  venue details of scarborough neighborhood

# %% [markdown]
# ![Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg](attachment:Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg)

# %% [markdown]
# ####  Grouping Locations based on Neighborhood

# %% [markdown]
# ![Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg](attachment:Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg)

# %% [markdown]
# ## Results

# %% [markdown]
# #### Cluster of Neighborhood

# %% [markdown]
# ![Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg](attachment:Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg)

# %% [markdown]
# #### Average price of houses in scarborough neighborhood

# %% [markdown]
# ![Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg](attachment:Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg)

# %% [markdown]
# #### School reviews  in scarborough neighborhood

# %% [markdown]
# ![Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg](attachment:Week5_%20The%20Battle%20of%20Neighborhoods%202%20-%20IBM%20Watson%20Studio%20-%20Google%20Chrome.jpg)

# %% [markdown]
# ##  Conclusion

# %% [markdown]
# In this project, using k-means cluster algorithm neighborhoods into 5 different clusters. Using cluster map, average prices in neighborhood graph and school review graph, people will be able to decide where they would like to relocate.
